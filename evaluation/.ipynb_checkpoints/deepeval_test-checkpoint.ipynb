# %%
from deepeval.metrics import HallucinationMetric
from deepeval.test_case import LLMTestCase
from deepeval import evaluate
import pandas as pd
from rich import print
from dotenv import load_dotenv
load_dotenv("../.env")
# Out:
# True

# %%
metric = HallucinationMetric()

# df = pd.read_csv(current_dir / "rag_run_dataset.csv")
df = pd.read_csv("graphrag_run_dataset.csv")
rag_df = pd.read_csv("rag_run_dataset.csv")

# %% [markdown]
# <h3>GRAPHRAG</h3>

# %%
test_cases = []

for _, row in df.iterrows():

    tc = LLMTestCase(
        input=row["question"],
        actual_output=row["generated_answer"],
        expected_output=row["expected_answer"],
        context=[row["retrieved_context"]],
    )

    test_cases.append(tc)

# %%
results = evaluate(
    test_cases=test_cases,
    metrics=[metric],
)
# Out:
# Evaluating 5 test case(s) in parallel ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━  80% 0:00:04
#     🎯 Evaluating test case #4        ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:04
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ 🚀 DeepEval Evaluation Results                                                                                  │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ ✅ test_case_0 (Passed 1 metrics)                                                                               │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  ❌ test_case_1                                                                                                 │
# │  ├──   Input:              Within how many calendar months of the injury must death or disablement occur for    │
# │  │                         an owner-driver personal accident benefit to be payable under a bundled private      │
# │  │                         car cover?                                                                           │
# │  │     Actual Output:      ## Owner-Driver Personal Accident Benefit Criteria                                   │
# │  │                                                                                                              │
# │  │                         Under a bundled private car insurance policy, the conditions regarding the           │
# │  │                         payment of personal accident benefits in the event of death or disablement are       │
# │  │                         specific to the timing of the occurrence. To qualify for the personal accident       │
# │  │                         benefit following an injury sustained by the owner-driver, the death or              │
# │  │                         disablement must occur within **six calendar months** of the accident.               │
# │  │                                                                                                              │
# │  │                         This time constraint is emphasized in the definition of personal accident            │
# │  │                         coverage, which states that the benefit provides compensation for bodily injury      │
# │  │                         sustained in direct connection with the use of the insured vehicle. The crucial      │
# │  │                         factor here is the stipulated time frame within which such an event must             │
# │  │                         transpire to trigger the insurer's liability for compensation [Data: Sources         │
# │  │                         (15), Entities (76); Relationships (65, 520)].                                       │
# │  │                                                                                                              │
# │  │                         ### Importance of Timeliness                                                         │
# │  │                                                                                                              │
# │  │                         The six-month requirement underscores the insurer's approach to managing risk and    │
# │  │                         benefits, reinforcing the necessity for timely reporting and processing of           │
# │  │                         claims. This stipulation is common across various insurance policies, ensuring       │
# │  │                         that claims are associated closely with the incident to prevent potential abuse      │
# │  │                         of the coverage options available.                                                   │
# │  │                                                                                                              │
# │  │                         In summary, for the owner-driver personal accident benefit to be payable, any        │
# │  │                         resulting death or disablement must occur within a six-month period following the    │
# │  │                         incident.                                                                            │
# │  │     Expected Output:    The death or disablement must occur within six calendar months of the injury for     │
# │  │                         compensation to be payable.                                                          │
# │  └── Metrics                                                                                                    │
# │       Status ┃ Metric        ┃ Score ┃ Threshold ┃ Reason                                                       │
# │      ━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  │
# │        FAIL  │ Hallucination │ 1.00  │ 0.50      │ The score is 1.00 because the actual output includes a       │
# │              │               │       │           │ specific claim about the owner-driver personal accident      │
# │              │               │       │           │ benefit requiring death or disablement within six calendar   │
# │              │               │       │           │ months, but the provided context does not support this and   │
# │              │               │       │           │ instead only generally describes personal accident cover     │
# │              │               │       │           │ subject to policy terms.                                     │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ ✅ test_case_2 (Passed 1 metrics)                                                                               │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ ✅ test_case_3 (Passed 1 metrics)                                                                               │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ ✅ test_case_4 (Passed 1 metrics)                                                                               │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Aggregate Metrics                                                                                               │
# │                                                                                                                 │
# │  Metric                           ┃ Average Score                    ┃ Pass Rate               ┃ Total          │
# │ ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━ │
# │  Hallucination                    │ 0.20                             │ 80.00%                  │ 5              │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ⚠ WARNING: No hyperparameters logged.
# » ]8;id=447260;https://deepeval.com/docs/evaluation-prompts\Log hyperparameters]8;;\ to attribute prompts and models to your test runs.
#
# ================================================================================
# ✓ Evaluation completed 🎉! (time taken: 4.83s | token cost: 0.1542475 USD)
# » Test Results (5 total tests):
#    » Pass Rate: 80.0% | Passed: 4 | Failed: 1
#
#  ================================================================================
#
# » Want to share evals with your team, or a place for your test cases to live? ❤️ 🏡
#   » Run 'deepeval view' to analyze and save testing results on Confident AI.

# %%
for i in range(len(results.test_results)):
    # i = 3
    # print(results.test_results[i].__dict__.keys())
    res = results.test_results[i]
    total_metrics = len(res.metrics_data)
    print(f"Name: {res.name} | Index: {res.index} | #Metrics: {total_metrics}\n\nQuestion: {res.input}")
    # print(results.test_results[0])
    # print(results.test_results[i].metrics_data[j].__dict__.keys())
    # print((results.test_results[i].metrics_data))
    
    for n_metric in range(total_metrics):
        met = res.metrics_data[n_metric]
        print(f"Metric: {met.name} | Threshold: {met.threshold} | Success: {met.success} | Score: {met.score} | Cost: ${met.evaluation_cost:.2f}\n\nReason: {met.reason}")
        print(f"Verdict: {met.verbose_logs.strip()}")
        # print(f"Verdict: {repr(met.verbose_logs.strip())}")
        # print(f"Verdict: {dict(met.verbose_logs.strip())}")
# Out:
# Name: test_case_2 | Index: 2 | #Metrics: 1
#
# Question: If an owner-driver is injured in an accident while under the influence of alcohol, is a personal accident
# claim payable under a private car own-damage-plus-liability cover?
# Metric: Hallucination | Threshold: 0.5 | Success: True | Score: 0.0 | Cost: $0.03
#
# Reason: The score is 0.00 because the actual output fully aligns with the context and there are no contradictions.
# Verdict: Verdicts:
# [
#     {
#         "verdict": "yes",
#         "reason": "The actual output agrees with the context. The context states that Personal Accident Cover for
# the insured/owner-driver excludes compensation when death or injury arises from an accident while the person is
# under the influence of intoxicating liquor or drugs. The output says an owner-driver injured while under the
# influence of alcohol would typically not be eligible for a personal accident claim, which is consistent and not
# contradictory."
#     }
# ]
# Name: test_case_0 | Index: 0 | #Metrics: 1
#
# Question: What is the total liability cap for the owner-driver personal accident cover bundled with a private car's
# own-damage and third-party cover, and what percentage of that sum is paid for accidental death?
# Metric: Hallucination | Threshold: 0.5 | Success: True | Score: 0.0 | Cost: $0.03
#
# Reason: The score is 0.00 because the actual output fully aligns with the provided context about IMT 15 coverage,
# conditions, and compensation limits, and no contradictions are present.
# Verdict: Verdicts:
# [
#     {
#         "verdict": "yes",
#         "reason": "The actual output agrees with the context. The context states that IMT 15 covers personal
# accident for the insured or named person other than paid driver/cleaner, applies while mounting, dismounting, or
# traveling in the insured vehicle, and that accidental death is compensated at 100% of the Capital Sum Insured, with
# the total liability capped by the CSI amount inserted in the policy."
#     }
# ]
# Name: test_case_3 | Index: 3 | #Metrics: 1
#
# Question: What depreciation rate is applied to rubber, nylon, plastic parts, tyres, tubes, batteries and air bags
# when they are replaced under an own-damage claim on a private car?
# Metric: Hallucination | Threshold: 0.5 | Success: True | Score: 0.0 | Cost: $0.03
#
# Reason: The score is 0.00 because the actual output fully aligns with the provided context and there are no
# contradictions or unsupported claims.
# Verdict: Verdicts:
# [
#     {
#         "verdict": "yes",
#         "reason": "The actual output agrees with the context. The source text for the private car package policy
# states that for replacements under loss or damage coverage, the depreciation for rubber/nylon/plastic parts, tyres
# and tubes, batteries, and air bags is 50%. The mention of an own-damage claim for a private car is consistent with
# that policy context, and the added explanation about compensation impact does not contradict the report."
#     }
# ]
# Name: test_case_1 | Index: 1 | #Metrics: 1
#
# Question: Within how many calendar months of the injury must death or disablement occur for an owner-driver
# personal accident benefit to be payable under a bundled private car cover?
# Metric: Hallucination | Threshold: 0.5 | Success: False | Score: 1.0 | Cost: $0.03
#
# Reason: The score is 1.00 because the actual output includes a specific claim about the owner-driver personal
# accident benefit requiring death or disablement within six calendar months, but the provided context does not
# support this and instead only generally describes personal accident cover subject to policy terms.
# Verdict: Verdicts:
# [
#     {
#         "verdict": "no",
#         "reason": "The actual output says the owner-driver personal accident benefit is payable only if death or
# disablement occurs within six calendar months, but the provided context does not state this specifically for the
# owner-driver benefit. The context says Personal Accident Cover offers compensation for bodily injuries linked to
# the insured vehicle and includes owner-driver and other passengers depending on policy terms, but it does not
# mention the six-month timing requirement. A correction would be to say only that personal accident cover
# compensates specified persons for bodily injury connected with use of the insured vehicle, subject to policy
# terms."
#     }
# ]
# Name: test_case_4 | Index: 4 | #Metrics: 1
#
# Question: What activities fall outside the permitted 'Limitations as to Use' for a privately used car covered under
# an own-damage-plus-liability cover, such that cover would not apply?
# Metric: Hallucination | Threshold: 0.5 | Success: True | Score: 0.0 | Cost: $0.03
#
# Reason: The score is 0.00 because the actual output is consistent with the provided context, accurately restating
# the listed vehicle-use limitations and introducing no direct contradictions.
# Verdict: Verdicts:
# [
#     {
#         "verdict": "yes",
#         "reason": "The actual output agrees with the context. The source text under 'CHAPTER 4 - Limitations as to
# Use' states that the policy covers use of the vehicle for any purpose other than hire or reward, carriage of goods
# other than samples of personal luggage, organised racing, pace making, reliability trials or speed testing, and any
# purpose in connection with motor trade. The actual output restates these exclusions in consistent terms. Its added
# phrasing about personal or commercial use without insurer consent is broader, but not a direct contradiction to the
# context."
#     }
# ]

# %% [markdown]
# <H3>RAG</H3>

# %%
test_cases = []

for _, row in rag_df.iterrows():

    tc = LLMTestCase(
        input=row["question"],
        actual_output=row["generated_answer"],
        expected_output=row["expected_answer"],
        context=[row["retrieved_context"]],
    )

    test_cases.append(tc)

# %%
rresults = evaluate(
    test_cases=test_cases,
    metrics=[metric],
)
# Out:
# Evaluating 5 test case(s) in parallel ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━  80% 0:00:09
#     🎯 Evaluating test case #4        ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:09
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ 🚀 DeepEval Evaluation Results                                                                                  │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ ✅ test_case_0 (Passed 1 metrics)                                                                               │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ ✅ test_case_1 (Passed 1 metrics)                                                                               │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ ✅ test_case_2 (Passed 1 metrics)                                                                               │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ ✅ test_case_3 (Passed 1 metrics)                                                                               │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  ❌ test_case_4                                                                                                 │
# │  ├──   Input:              What activities fall outside the permitted 'Limitations as to Use' for a             │
# │  │                         privately used car covered under an own-damage-plus-liability cover, such that       │
# │  │                         cover would not apply?                                                               │
# │  │     Actual Output:      Under a privately used car policy that includes own-damage-plus-liability cover,     │
# │  │                         there are specific activities that fall outside the permitted 'Limitations as to     │
# │  │                         Use,' which would result in the cover not applying. These limitations include:       │
# │  │                                                                                                              │
# │  │                         1. **Use Outside Insured's Premises**: The insurer will not be liable if the         │
# │  │                         vehicle is used elsewhere than on the insured's premises, except for specific        │
# │  │                         missions such as fighting a fire. The term 'use confined to own premises' refers     │
# │  │                         to use only on premises where the public does not have general access [Data:         │
# │  │                         3-years-private-car-liability-policy.txt;                                            │
# │  │                         goods-carrying-vehicle-liability-policy-wording.txt].                                │
# │  │                                                                                                              │
# │  │                         2. **Use for Commercial Purposes**: The policy is intended for social, domestic,     │
# │  │                         or pleasure purposes. If the vehicle is used for commercial activities or            │
# │  │                         purposes not covered under the policy, such as carrying goods for hire or reward,    │
# │  │                         the cover would not apply [Data: 3-years-private-car-liability-policy.txt].          │
# │  │                                                                                                              │
# │  │                         3. **Use by Unauthorized Persons**: The vehicle must be used by the insured or       │
# │  │                         with their permission by a member, director, or employee of the insured. If the      │
# │  │                         vehicle is used by someone who is not authorized or does not meet the criteria       │
# │  │                         set forth in the policy, the cover would be void [Data:                              │
# │  │                         3-years-private-car-liability-policy.txt].                                           │
# │  │                                                                                                              │
# │  │                         4. **Indemnity Under Another Policy**: If the person using the vehicle is            │
# │  │                         entitled to indemnity under another insurance policy, the cover under this policy    │
# │  │                         would not apply [Data: 3-years-private-car-liability-policy.txt].                    │
# │  │                                                                                                              │
# │  │                         5. **Refusal of Insurance**: If the person using the vehicle has been refused        │
# │  │                         motor vehicle insurance by any insurer, the cover would not apply [Data:             │
# │  │                         3-years-private-car-liability-policy.txt].                                           │
# │  │                                                                                                              │
# │  │                         These limitations are crucial for ensuring that the insurance coverage remains       │
# │  │                         valid and that the insured understands the boundaries of their policy.               │
# │  │     Expected Output:    Cover excludes use for hire or reward, carriage of goods (other than samples or      │
# │  │                         personal luggage), organised racing, pace making, reliability trials or speed        │
# │  │                         testing, and any purpose connected with motor trade.                                 │
# │  └── Metrics                                                                                                    │
# │       Status ┃ Metric        ┃ Score ┃ Threshold ┃ Reason                                                       │
# │      ━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  │
# │        FAIL  │ Hallucination │ 1.00  │ 0.50      │ The score is 1.00 because the actual output makes broad      │
# │              │               │       │           │ exclusion and voidance claims that are not supported by      │
# │              │               │       │           │ the context, which only describes specific endorsements,     │
# │              │               │       │           │ permitted users, and limited site/premises restrictions.     │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Aggregate Metrics                                                                                               │
# │                                                                                                                 │
# │  Metric                           ┃ Average Score                    ┃ Pass Rate               ┃ Total          │
# │ ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━ │
# │  Hallucination                    │ 0.20                             │ 80.00%                  │ 5              │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ⚠ WARNING: No hyperparameters logged.
# » ]8;id=235257;https://deepeval.com/docs/evaluation-prompts\Log hyperparameters]8;;\ to attribute prompts and models to your test runs.
#
# ================================================================================
# ✓ Evaluation completed 🎉! (time taken: 9.2s | token cost: 0.04145 USD)
# » Test Results (5 total tests):
#    » Pass Rate: 80.0% | Passed: 4 | Failed: 1
#
#  ================================================================================
#
# » Want to share evals with your team, or a place for your test cases to live? ❤️ 🏡
#   » Run 'deepeval view' to analyze and save testing results on Confident AI.

# %%
for i in range(len(rresults.test_results)):
    # i = 3
    # print(results.test_results[i].__dict__.keys())
    res = rresults.test_results[i]
    total_metrics = len(res.metrics_data)
    print(f"Name: {res.name} | Index: {res.index} | #Metrics: {total_metrics}\n\nQuestion: {res.input}")
    print(f"Context: {res.context[0}")
    # print(results.test_results[0])
    # print(results.test_results[i].metrics_data[j].__dict__.keys())
    
    for n_metric in range(total_metrics):
        met = res.metrics_data[n_metric]
        print(f"Metric: {met.name} | Threshold: {met.threshold} | Success: {met.success} | Score: {met.score} | Cost: ${met.evaluation_cost:.2f}\n\nReason: {met.reason}")
        print(f"Verdict: {met.verbose_logs.strip()}")
        # print(f"Verdict: {repr(met.verbose_logs.strip())}")
        # print(f"Verdict: {dict(met.verbose_logs.strip())}")
# Out:
# Name: test_case_0 | Index: 0 | #Metrics: 1
#
# Question: What is the total liability cap for the owner-driver personal accident cover bundled with a private car's
# own-damage and third-party cover, and what percentage of that sum is paid for accidental death?
# Context: ['Source: private-car-package-policy-wording.txt\nthan one person any limitation by the terms of this
# Policy\n     and/or of any Endorsement thereon of the amount of any\n    indemnity shall apply to the aggregate
# amount of\n    indemnity to all persons indemniﬁed and such indemnity\n     shall apply in priority to the
# insured.\nSection  III - PERSONAL ACCIDENT COVER FOR OWNER-\nDRIVER\nThe Company undertakes to pay compensation as
# per the\nfollowing scale for bodily injury/death sustained by the owner-\ndriver of the vehicle, in direct
# connection with the vehicle insured\nor whilst driving or mounting into/dismounting from the vehicle\ninsured or
# whilst traveling in it as a co-driver, caused by violent\naccidental external and visible means which independent
# of\nany other cause shall within six calendar months of such injury\nresult in:\n\nSource:
# 3-years-private-car-liability-policy.txt\n(iii) Loss of one limb or sight of one eye       50%\n (iv) Permanent
# total disablement from inju\xad                                  100%     ries other than named above.\nProvided
# always that\nI.   Compensation shall be payable under only one of the\n    items (i) to (iv) above in respect of
# the owner-driver arising\n    out of any one occurrence and the total liability of the\n    insurer shall not in
# the aggregate exceed the sum of ₹ 15\n    lakhs during any one period of insurance.\nII.  No compensation shall be
# payable in respect of death or\n    bodily injury directly or indirectly wholly or in part arising\n    or
# resulting from or traceable to (1) intentional self-injury\n    suicide or attempted suicide physical defect or
# infirmity or\n     (2) an accident happening whilst such person is under the\n    influence of intoxicating liquor
# or drugs.\n    Such compensation shall be payable directly to the insured\n    or to his/her legal representatives
# whose receipt shall be\n    the full discharge in respect of the injury to the insured.\n     a.  This cover is
# subject to\n                 i.   The owner-driver is the registered owner of the\n             vehicle insured
# herein;\n\nSource: private-car-package-policy-wording.txt\nProvided always that\nI.    Compensation shall be
# payable under only one of the\n     items (i) to (iv) above in respect of the owner-driver arising\n     out of any
# one occurrence and the total liability of the\n      insurer shall not in the aggregate exceed the sum of ` 15\n
# lakhs during any one period of insurance.\nII.   No compensation shall be payable in respect of death or\n
# bodily injury directly or indirectly wholly or in part arising\n      or resulting from or traceable to (1)
# intentional self injury\n      suicide or attempted suicide physical defect or inﬁrmity or\n      (2) an accident
# happening whilst such person is under the\n     inﬂuence of intoxicating liquor or drugs.\nIII.   Such compensation
# shall be payable directly to the\n     insured or to his/her legal representatives whose receipt\n      shall be
# the full discharge in respect of the injury to the\n      insured.\n      a. This cover is subject to\n
# i.  The owner-driver is the registered owner of the\n            vehicle insured herein;\n                 ii.  The
# owner-driver  is the insured named in this\n              policy.\n\nSource:
# 3-years-private-car-liability-policy.txt\nvehicle insured herein;\n                 ii.  The owner-driver is the
# insured named in this\n               policy.\n                 iii.  The  owner-driver  holds an  effective
# driving\n              license, in accordance with the provisions of Rule\n          3 of the Central Motor
# Vehicles Rules, 1989, at\n            the time of the accident.\nIII.  The personal accident cover for owner driver
# is mandatory\n     for a period of one year and may be extended, in line with\n    the duration of policy, at the
# discretion of the customer.\nCHAPTER 2 - EXCEPTION AND CONDITION\n1.  GENERAL EXCEPTIONS\n   The Company shall not
# be liable under this Policy in\n    respect of\n     1.  Any accidental loss or damage and/or liability caused\n
# sustained or incurred outside the geographical area;\n     2.  Any claim arising out of any contractual
# liability;\n     3.  Any accidental loss damage and/or liability caused\n        sustained or incurred whilst the
# vehicle insured herein\n           is\n         a)  Being used otherwise than in accordance with\n
# the. Limitations as to Use. or\n         b)  Being driven by or is for the purpose of being\n\nSource:
# goods-carrying-vehicle-liability-policy-wording.txt\nProvided always that\nI.   The compensation shall be payable
# under only one of\n    the items (i) to (iv) above in respect of the owner-driver\n     arising out of any one
# occurrence and the total liability of\n    the insurer shall not in the aggregate exceed the sum of `\n   15 Lakhs
# during any one period of insurance.\nII.  No compensation shall be payable in respect of death or\n    bodily
# injury directly or indirectly wholly or in part arising\n    or resulting from or traceable to\n(a)  intentional
# self injury suicide or attempted suicide physical\n    defect or infirmity or (b) an accident happening whilst\n
# such person is under the influence of intoxicating liquor or\n    drugs.\nThis cover is subject to\n     a.  The
# owner-driver is the registered owner of the vehicle\n         insured herein;\n      b.  The owner-driver is the
# insured named in this policy.\n      c.  The owner-driver holds an effective driving license,\n           in
# accordance with the provisions of Rule 3 of the\n         Central Motor Vehicles Rules, 1989, at the time of the\n
# accident.\nIII.  The personal accident cover for owner driver is mandatory']
# Metric: Hallucination | Threshold: 0.5 | Success: True | Score: 0.0 | Cost: $0.01
#
# Reason: The score is 0.00 because the actual output is fully supported by the context: it correctly states the ₹15
# lakh liability limit for owner-driver personal accident cover and that accidental death is compensated at 100%,
# with no contradictions present.
# Verdict: Verdicts:
# [
#     {
#         "verdict": "yes",
#         "reason": "The actual output agrees with the context. The context states that for owner-driver personal
# accident cover, the insurer's total liability shall not exceed \u20b915 lakhs during any one period of insurance.
# It also supports that accidental death is compensated at 100% under the listed scale, so saying the full \u20b915
# lakhs would be paid for accidental death is consistent with this context."
#     }
# ]
# Name: test_case_1 | Index: 1 | #Metrics: 1
#
# Question: Within how many calendar months of the injury must death or disablement occur for an owner-driver
# personal accident benefit to be payable under a bundled private car cover?
# Context: ['Source: private-car-package-policy-wording.txt\nthan one person any limitation by the terms of this
# Policy\n     and/or of any Endorsement thereon of the amount of any\n    indemnity shall apply to the aggregate
# amount of\n    indemnity to all persons indemniﬁed and such indemnity\n     shall apply in priority to the
# insured.\nSection  III - PERSONAL ACCIDENT COVER FOR OWNER-\nDRIVER\nThe Company undertakes to pay compensation as
# per the\nfollowing scale for bodily injury/death sustained by the owner-\ndriver of the vehicle, in direct
# connection with the vehicle insured\nor whilst driving or mounting into/dismounting from the vehicle\ninsured or
# whilst traveling in it as a co-driver, caused by violent\naccidental external and visible means which independent
# of\nany other cause shall within six calendar months of such injury\nresult in:\n\nSource:
# private-car-package-policy-wording.txt\nii.  The owner-driver  is the insured named in this\n
# policy.\n                 iii. The owner-driver holds an effective driving license,\n              in accordance
# with the provisions of Rule 3 of the\n            Central Motor Vehicles Rules, 1989, at the time of\n
# the accident.\nIV.   The personal accident cover for owner driver is mandatory\n      for a period of one year and
# may be extended, in line with\n     the duration of policy, at the discretion of the customer”\n\nSource:
# compulsory-personal-accident-owner-driver-policy-wording.txt\nProduct Code: 3012   UIN: IR\n\nCHAPTER 1  - STANDARD
# FORM FOR COMPULSORY\nPERSONAL ACCIDENT (OWNER-DRIVER) UNDER MOTOR\nINSURANCE POLICY\nThe Company undertakes to pay
# compensation as per the\nfollowing scale for bodily injury/ death sustained by the owner-\ndriver of the vehicle,
# in direct connection with the vehicle or\nwhilst driving or mounting into/dismounting from the vehicle or\nwhilst
# traveling in it as a co-driver, caused by violent accidental\nexternal and visible means which independent of any
# other\ncause shall within six calendar months of such injury result in:\n\nSource:
# goods-carrying-vehicle-liability-policy-wording.txt\naccident.\nIII.  The personal accident cover for owner driver
# is mandatory\n     for a period of one year and may be extended, in line with\n    the duration of policy, at the
# discretion of the customer\n\nSource: 3-years-private-car-liability-policy.txt\n(iii) Loss of one limb or sight of
# one eye       50%\n (iv) Permanent total disablement from inju\xad                                  100%     ries
# other than named above.\nProvided always that\nI.   Compensation shall be payable under only one of the\n    items
# (i) to (iv) above in respect of the owner-driver arising\n    out of any one occurrence and the total liability of
# the\n    insurer shall not in the aggregate exceed the sum of ₹ 15\n    lakhs during any one period of
# insurance.\nII.  No compensation shall be payable in respect of death or\n    bodily injury directly or indirectly
# wholly or in part arising\n    or resulting from or traceable to (1) intentional self-injury\n    suicide or
# attempted suicide physical defect or infirmity or\n     (2) an accident happening whilst such person is under the\n
# influence of intoxicating liquor or drugs.\n    Such compensation shall be payable directly to the insured\n    or
# to his/her legal representatives whose receipt shall be\n    the full discharge in respect of the injury to the
# insured.\n     a.  This cover is subject to\n                 i.   The owner-driver is the registered owner of
# the\n             vehicle insured herein;']
# Metric: Hallucination | Threshold: 0.5 | Success: True | Score: 0.0 | Cost: $0.01
#
# Reason: The score is 0.00 because the actual output fully aligns with the context, correctly stating the six-month
# requirement for death or disablement, and there are no contradictions.
# Verdict: Verdicts:
# [
#     {
#         "verdict": "yes",
#         "reason": "The actual output agrees with the context. The context states that for owner-driver personal
# accident cover, bodily injury/death caused by an accident must, within six calendar months of the injury, result in
# the listed outcomes. The actual output accurately reflects this six-month requirement for death or disablement."
#     }
# ]
# Name: test_case_2 | Index: 2 | #Metrics: 1
#
# Question: If an owner-driver is injured in an accident while under the influence of alcohol, is a personal accident
# claim payable under a private car own-damage-plus-liability cover?
# Context: ['Source: compulsory-personal-accident-owner-driver-policy-wording.txt\nor resulting from or traceable to
# (1) intentional self injury,\n   suicide or attempted suicide physical defect or infirmity\n   or (2) an accident
# happening whilst such person is under\n   the influence of intoxicating liquor, drugs or any other\n   substance
# abuse.\nIII. Such compensation shall be payable directly to the insured or\n   to his/her legal
# representatives/Nominee whose receipt shall\n   be the full discharge in respect of the injury to the insured.\nIV.
# This cover is subject to\n      a. The owner-driver  is the registered owner of the\n         vehicle whilst
# driving which, including mounting into/\n        dismounting from or traveling in, the owner-driver\n
# sustained bodily injury/ death;\n      b. The owner-driver is the insured named under this\n         policy and the
# policy being valid on the date of loss\nRDAN115RP0034V01201819\n\nSource:
# 3-years-private-car-liability-policy.txt\nor infirmity or (b) an accident happening whilst such\n        person is
# under the influence of intoxicating liquor or\n        drugs.\n        III.  Such compensation shall be payable
# only with the\n        approval of the insured named in the policy and directly\n         to the injured person or
# his/her legal representative(s)\n       whose receipt shall be a full discharge in respect of\n        the injury
# of such person.\n        Subject otherwise to the terms exceptions conditions\n       and limitations of this
# policy.\n       *The Capital Sum Insured (CSI) per passenger is to be\n         inserted.\n15. IMT.  16.  PERSONAL
# ACCIDENT  TO  UNNAMED\n   PASSENGERS OTHER THAN INSURED AND THE PAID\n   DRIVER AND CLEANER (For vehicles rated as
# Private\n    cars and Motorised two wheelers (not for hire or reward)\n    with or without side car)\n     In
# consideration of the payment of an additional premium\n       it  is hereby understood and agreed that the
# insurer\n    undertakes to pay compensation on the scale provided\n    below for bodily injuries hereinafter
# defined sustained\n    by any passenger other than the insured and/or the paid\n\nSource:
# goods-carrying-vehicle-liability-policy-wording.txt\nProvided always that\nI.   The compensation shall be payable
# under only one of\n    the items (i) to (iv) above in respect of the owner-driver\n     arising out of any one
# occurrence and the total liability of\n    the insurer shall not in the aggregate exceed the sum of `\n   15 Lakhs
# during any one period of insurance.\nII.  No compensation shall be payable in respect of death or\n    bodily
# injury directly or indirectly wholly or in part arising\n    or resulting from or traceable to\n(a)  intentional
# self injury suicide or attempted suicide physical\n    defect or infirmity or (b) an accident happening whilst\n
# such person is under the influence of intoxicating liquor or\n    drugs.\nThis cover is subject to\n     a.  The
# owner-driver is the registered owner of the vehicle\n         insured herein;\n      b.  The owner-driver is the
# insured named in this policy.\n      c.  The owner-driver holds an effective driving license,\n           in
# accordance with the provisions of Rule 3 of the\n         Central Motor Vehicles Rules, 1989, at the time of the\n
# accident.\nIII.  The personal accident cover for owner driver is mandatory\n\nSource:
# 3-years-private-car-liability-policy.txt\nany statutory provisions or judicial pronouncements.\n4.  In respect of a
# claim made or considered against the\n   Company or third-party claim under the same policy.\n5.   If the Insured
# Person is driving the insured vehicle under\n    the influence of alcohol, drugs, or any other intoxicating\n
# substances, the claim shall not be admissible. Additionally,\n   no expenses will be covered for any other person
# driving\n    the insured vehicle under such influence, nor will expenses\n    related to the release of the vehicle
# in such circumstances\n   be covered.\n6.  For any claims arising from, based upon, or attributable\n    to a
# wrongful act or circumstance known to the Insured\n    Person, or that the Insured Person reasonably should have\n
# known, prior to the inception date of this policy.\nConditions:\n1.  The Coverage shall not apply to vehicles used
# for racing,\n    rallying, motorsports, or any  similar  activities, nor to\n    instances where the vehicle is
# operated in violation of\n    applicable laws in force at the time of use.\n2.  The Coverage shall not be available
# for Acts of God events,\n    including natural disasters or other unforeseeable events\n   beyond human
# control.\n\nSource: 3-years-private-car-liability-policy.txt\n(iii) Loss of one limb or sight of one eye
# 50%\n (iv) Permanent total disablement from inju\xad                                  100%     ries other than
# named above.\nProvided always that\nI.   Compensation shall be payable under only one of the\n    items (i) to (iv)
# above in respect of the owner-driver arising\n    out of any one occurrence and the total liability of the\n
# insurer shall not in the aggregate exceed the sum of ₹ 15\n    lakhs during any one period of insurance.\nII.  No
# compensation shall be payable in respect of death or\n    bodily injury directly or indirectly wholly or in part
# arising\n    or resulting from or traceable to (1) intentional self-injury\n    suicide or attempted suicide
# physical defect or infirmity or\n     (2) an accident happening whilst such person is under the\n    influence of
# intoxicating liquor or drugs.\n    Such compensation shall be payable directly to the insured\n    or to his/her
# legal representatives whose receipt shall be\n    the full discharge in respect of the injury to the insured.\n
# a.  This cover is subject to\n                 i.   The owner-driver is the registered owner of the\n
# vehicle insured herein;']
# Metric: Hallucination | Threshold: 0.5 | Success: True | Score: 0.0 | Cost: $0.01
#
# Reason: The score is 0.00 because the actual output fully aligns with the context and there are no contradictions;
# both state that no compensation is payable if the owner-driver was under the influence at the time of the accident.
# Verdict: Verdicts:
# [
#     {
#         "verdict": "yes",
#         "reason": "The actual output agrees with the context. The context states that no compensation is payable
# for death or bodily injury arising from an accident while the person is under the influence of intoxicating liquor,
# drugs, or substance abuse, which matches the output's statement that an owner-driver intoxicated at the time of the
# accident would have the claim denied."
#     }
# ]
# Name: test_case_3 | Index: 3 | #Metrics: 1
#
# Question: What depreciation rate is applied to rubber, nylon, plastic parts, tyres, tubes, batteries and air bags
# when they are replaced under an own-damage claim on a private car?
# Task was destroyed but it is pending!
# task: <Task pending name='Task-473' coro=<_async_in_context.<locals>.run_in_context() running at /Users/dpratik1618/Pratik/Personal/Career/Pratik/Creospan/graphrag_POC/.venv/lib/python3.12/site-packages/ipykernel/utils.py:60> wait_for=<Task pending name='Task-476' coro=<Kernel.shell_main() running at /Users/dpratik1618/Pratik/Personal/Career/Pratik/Creospan/graphrag_POC/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py:597> cb=[Task.__wakeup()]> cb=[ZMQStream._run_callback.<locals>._log_error() at /Users/dpratik1618/Pratik/Personal/Career/Pratik/Creospan/graphrag_POC/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py:563]>
# /Users/dpratik1618/Pratik/Personal/Career/Pratik/Creospan/graphrag_POC/.venv/lib/python3.12/site-packages/rich/text.py:761: RuntimeWarning: coroutine 'Kernel.shell_main' was never awaited
#   styles = tuple(style_map[_style_id] for _style_id in sorted(stack))
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# Task was destroyed but it is pending!
# task: <Task pending name='Task-476' coro=<Kernel.shell_main() running at /Users/dpratik1618/Pratik/Personal/Career/Pratik/Creospan/graphrag_POC/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py:597> cb=[Task.__wakeup()]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-477' coro=<_async_in_context.<locals>.run_in_context() running at /Users/dpratik1618/Pratik/Personal/Career/Pratik/Creospan/graphrag_POC/.venv/lib/python3.12/site-packages/ipykernel/utils.py:60> wait_for=<Task pending name='Task-480' coro=<Kernel.shell_main() running at /Users/dpratik1618/Pratik/Personal/Career/Pratik/Creospan/graphrag_POC/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py:597> cb=[Task.__wakeup()]> cb=[ZMQStream._run_callback.<locals>._log_error() at /Users/dpratik1618/Pratik/Personal/Career/Pratik/Creospan/graphrag_POC/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py:563]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-480' coro=<Kernel.shell_main() running at /Users/dpratik1618/Pratik/Personal/Career/Pratik/Creospan/graphrag_POC/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py:597> cb=[Task.__wakeup()]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-484' coro=<Kernel.shell_main() running at /Users/dpratik1618/Pratik/Personal/Career/Pratik/Creospan/graphrag_POC/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py:597> cb=[Task.__wakeup()]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-485' coro=<_async_in_context.<locals>.run_in_context() running at /Users/dpratik1618/Pratik/Personal/Career/Pratik/Creospan/graphrag_POC/.venv/lib/python3.12/site-packages/ipykernel/utils.py:60> wait_for=<Task pending name='Task-487' coro=<Kernel.shell_main() running at /Users/dpratik1618/Pratik/Personal/Career/Pratik/Creospan/graphrag_POC/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py:597> cb=[Task.__wakeup()]> cb=[ZMQStream._run_callback.<locals>._log_error() at /Users/dpratik1618/Pratik/Personal/Career/Pratik/Creospan/graphrag_POC/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py:563]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-481' coro=<_async_in_context.<locals>.run_in_context() running at /Users/dpratik1618/Pratik/Personal/Career/Pratik/Creospan/graphrag_POC/.venv/lib/python3.12/site-packages/ipykernel/utils.py:60> wait_for=<Task pending name='Task-484' coro=<Kernel.shell_main() running at /Users/dpratik1618/Pratik/Personal/Career/Pratik/Creospan/graphrag_POC/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py:597> cb=[Task.__wakeup()]> cb=[ZMQStream._run_callback.<locals>._log_error() at /Users/dpratik1618/Pratik/Personal/Career/Pratik/Creospan/graphrag_POC/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py:563]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-487' coro=<Kernel.shell_main() running at /Users/dpratik1618/Pratik/Personal/Career/Pratik/Creospan/graphrag_POC/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py:597> cb=[Task.__wakeup()]>
# Context: ["Source: private-car-package-policy-wording.txt\nVI.  By accidental external means;\n\nVII.  By malicious
# act;\n\nVIII. By terrorist activity;\n\nIX.   Whilst in transit by road rail inland-waterway lift elevator\n
# or air;\n\nX.   By landslide rockslide.\n\nSubject to a deduction for depreciation at the rates mentioned\nbelow in
# respect of parts replaced :\nI.    For  all rubber/nylon/plastic parts, tyres and tubes,\n      batteries and air
# bags-50%\n\nII.    For ﬁbre glass components-30%\n\nIII.   For all parts made of glass-Nil\n\nIV.   Rate of
# depreciation for all other parts including wooden\n     parts will be as per the following schedule.\n  AGE OF THE
# VEHICLE     % OF DEPRECIATION\n\n   Not exceeding 6 months                    Nil\n   Exceeding 6 months but not\n
# exceeding 1 year               5%\n\n   Exceeding 1 year but not\n   exceeding 2 years               10%\n
# Exceeding 2 years but not\n   exceeding 3 years               15%\n\n   Exceeding 3 years but not\n   exceeding 4
# years               25%\n   Exceeding 4 years but not\n   exceeding 5 years               35%\n\nSource:
# private-car-package-policy-wording.txt\nExceeding 5 years but not\n   exceeding 10 years              40%\n
# Exceeding 10 years              50%\nV.   Rate of Depreciation for Painting: In the case of painting,\n     the
# depreciation rate of 50% shall be applied only on the\n     material cost of total painting charges. In case of a\n
# consolidated  bill for painting charges,the material\n     component shall be considered as 25% of the total\n
# painting charges for the purpose of applying the\n      depreciation.\nThe Company shall not be liable to make any
# payment in respect\nof:-\na.   Consequential loss, depreciation, wear and tear,\n     mechanical or electrical
# breakdown, failures or breakages;\nb.   Damage to tyres and tubes unless the vehicle is damaged\n      at the same
# time in which case the liability of the company\n      shall be limited to 50%of the cost of replacement and\nc.
# Any accidental loss or damage suffered whilst the insured\n      or any person driving the vehicle with the
# knowledge and\n     consent of the insured is under the inﬂuence of intoxicating\n      liquor or drugs.\nIn the
# event of the vehicle being disabled by reason of loss or\ndamage covered under this Policy the Company will bear
# the\n\nSource: private-car-package-policy-wording.txt\ntheft under any circumstances) to lamps
# tyres/tubes\nmudguards bonnet/side parts bumpers headlights and\npaintwork of damaged portion only is covered
# provided the\nvehicle is also damaged at the same time. Subject to:\nI.   Depreciation as per schedule provided in
# Section 1 of the\n     policy. It is further understood and agreed that in respect of\n    paint work for the
# damaged portion only (as referred to\n    above) shall also be as per schedule provided in Section 1 of\n    the
# policy.\nII.   In addition to any amount which the insured may be\n    required to bear under para (a) above, the
# insured shall also\n    bear 50% of the assessed loss in respect of each and every\n    claim under this
# Endorsement.\nIII.   It is also understood that no deductible other than those\n    mentioned in (a) and (b) above
# shall be applicable in\n    respect of a claim which become payable under this\n    Endorsement.\nSubject otherwise
# to the terms conditions limitations and\nexceptions of this Policy.\n* To insert the sum arrived at as per the
# provisions of G.R.40.\nNB.3. of the Tariff.\n25. IMT. 24. ELECTRICAL  / ELECTRONIC FITTINGS (Items\nﬁtted in the
# vehicle but not included in the manufacturer’\n\nSource: private-car-package-policy-wording.txt\n1.  Zero
# depreciation\nUIN:IRDAN115RP0017V01200102/A0368V01200910\nIn consideration of the payment of an additional premium
# by the\nInsured as mentioned in policy schedule, it is hereby agreed and\ndeclared that notwithstanding anything to
# the contrary\ncontained in the Policy, the Company hereby undertakes to\ndeduct no amounts for depreciation in case
# of parts replaced on\naccount of damage to the vehicle insured and/or to  its\naccessories, arising out of any
# peril as covered under the Policy.\nProvided always that\nI.  Such claim has been admitted by the Company under
# Section I\n   - “Loss or Damage to the Vehicles Insured” of the Policy,\nII.  This add-on shall not be applicable
# in the event of Total Loss/\n   Constructive Total Loss/Cash loss of the vehicle insured\n   under the
# Policy,\nIII. The Insured shall be liable for the Voluntary Deductible*\n   amount, as opted by the Insured for
# this add-on, for each and\n   every claim payable under this add-on,\nIV. This add-on shall not be applicable for
# any minor scratches\n   to the vehicle, paint fading, wear and tear arising out of\n   normal use and requiring
# touch-up or minor repair under\n   routine maintenance\n\nSource: private-car-package-policy-wording.txt\ncustomer
# purchasing ICICI Lombard GIC Company Limited\n   Comprehensive Motor Insurance Policy.\n4. Whenever replacement of
# tyre(s) and/or tube(s) will be\n   allowed, it will be of the same make and speciﬁcation as\n   ﬁtted by the OEM's.
# However, if tyre(s) and/or tube(s) of\n    similar speciﬁcation is not available and replaced tyre(s)\n   and/or
# tube(s) is/are superior to damaged one then we will\n   not be liable for differential amount.\n5. Maximum of 4
# (four) replacements of tyre(s) and/or tube(s)\n    will be allowed during the Period of Insurance ie. for policy\n
# of 12 months.\n6.  In case of replacement of four tyre(s) and/or tube(s) for\n   which a claim is preferred under
# the coverage, replaced\n    tyre(s) and/or tube(s) can be reinstated by way of\n   endorsement by paying requisite
# premium.\n7.   If damage to tyre(s) and/or tube(s) is/are due to the\n   accidental damage to the insured vehicle
# covered under\n  “Own Damage” section of the policy. ICICI Lombard GIC\n   Company Limited liability under this
# cover will be restricted\n    to the difference of depreciation percentage applied under\n  “Own Damage” section
# and as mentioned above basis the\n   unused tread depth."]
# Metric: Hallucination | Threshold: 0.5 | Success: True | Score: 0.0 | Cost: $0.01
#
# Reason: The score is 0.00 because the actual output fully aligns with the provided context about 50% depreciation
# for the listed parts and the resulting reduction in the claim amount, with no contradictions present.
# Verdict: Verdicts:
# [
#     {
#         "verdict": "yes",
#         "reason": "The actual output agrees with the context stating that for all rubber/nylon/plastic parts, tyres
# and tubes, batteries, and air bags, a 50% depreciation applies when parts are replaced. The output is also
# consistent with the claim amount being reduced by that depreciation. The extra phrase calling it 'standard' is not
# contradicted by the context."
#     }
# ]
# Name: test_case_4 | Index: 4 | #Metrics: 1
#
# Question: What activities fall outside the permitted 'Limitations as to Use' for a privately used car covered under
# an own-damage-plus-liability cover, such that cover would not apply?
# Context: ["Source: 3-years-private-car-liability-policy.txt\nherein to the contrary it is hereby understood and
# agreed\n    that this Policy shall be operative whilst the vehicle insured\n     is being used by the insured or
# with the permission of the\n    insured by a Member Director or employee of the insured\n     for social domestic
# or pleasure purposes.\n    Whilst the vehicle insured is being so used the insurer will\n     in terms of and
# subject to the limitations of and for the\n    purpose of Section II of this policy treat as though he were\n
# the insured person using the vehicle insured provided that\n    such person :\n     1.   Is not entitled to
# indemnity under any other policy;\n     2.   Shall as though he/she were the insured observe fulfill\n       and be
# subject to the terms provisions conditions and\n       endorsements of this policy in so far as they apply;\n
# 3.  Has not been refused any Motor Vehicle Insurance or\n        continuance thereof by any insurer.\n
# Subject otherwise to the terms conditions limitations\n       and exceptions of this Policy.\n60. IMT.   60.
# DEMONSTRATION-DRIVING  EXTENSION\n    (Applicable to Motor Trade Policies Only)\n     In consideration of the
# payment of an additional premium\n\nSource: private-car-package-policy-wording.txt\nendorsement to this effect
# having been incorporated in the\nRegistration Book by the Registering Authority, a discount of\n50% on the Own
# Damage premium for the vehicle insured is\nhereby allowed to the insured.\nSubject otherwise to the terms
# exceptions conditions and\nlimitations of the policy.\n13.  IMT. 13. USE OF VEHICLE WITHIN INSURED’S OWN\nPREMISES
# (Applicable to all classes except as otherwise\nprovided in the tariff)\nIt is hereby understood and agreed that
# the insurer shall not be\nliable in respect of the vehicle insured while the vehicle is being\nused elsewhere than
# in the insured's premises except where the\nvehicle is speciﬁcally required for a mission to ﬁght a ﬁre.\nFor the
# purposes of this endorsement 'Use conﬁned to own\npremises' shall mean use only on insured's premises to
# which\npublic have no general right of access.\n14.     IMT. 14. USE OF VEHICLE CONFINED TO SITES\n(Applicable to
# Goods Carrying Vehicles)\nIt is hereby understood and agreed that the insurer shall not be\nliable in respect of
# the vehicle insured while it is being used\nelsewhere than on site to which the public have no general right\nof
# access and the vehicle is not required to be registered under\n\nSource:
# 3-years-private-car-liability-policy.txt\nself ignition or lightning or burglary housebreaking or\n
# theft.\n     b.  Under Section II except so far as is necessary to meet\n        the requirements of the Motor
# Vehicles Act, 1988, in\n        respect of liability incurred by the insured arising out\n         of the operation
# as a tool of such vehicle or of plant\n        forming part of such vehicle or attached thereto.\n        N. B.:
# Omit paragraph (a) for:-\n          1.   Liability only Policies.\n          2.  Package Policies where an
# additional premium\n           has been paid  for  inclusion  of damage by\n             overturning.\n
# NOTE:  *Insert make, number  or some other\n          means of identification.\n          Where a premium
# reduction  is allowed  for\n             exclusion of damage when  in use as a tool\n             of trade omit
# from paragraph (a) (the words\n              resulting from “overturning” and “except for loss”\n             or
# “theft”.\n48. IMT. 48. AGRICULTURAL AND FORESTRY VEHICLES\n   AND  OTHER  MISCELLANEOUS  VEHICLES  WITH\n
# TRAILERS ATTACHED-EXTENDED COVER\n       It is hereby declared and agreed that in consideration of\n\nSource:
# goods-carrying-vehicle-liability-policy-wording.txt\nprovided in the tariff)\n       It is hereby understood and
# agreed that the insurer shall\n    not be liable in respect of the vehicle insured while the\n     vehicle is being
# used elsewhere than in the insured’s\n    premises except where the vehicle is specifically required\n     for a
# mission to fight a fire.\n    For the purposes of this endorsement “Use confined to\n   own premises” shall mean
# use only on insured’s premises\n     to which public have no general right\n 14. IMT.  14. USE OF VEHICLE CONFINED
# TO  SITES\n    (Applicable to Goods Carrying Vehicles)\n       It is hereby understood and agreed that the insurer
# shall\n    not be liable in respect of the vehicle insured while it is\n    being used elsewhere than on site to
# which the public have\n    no general right of access and the vehicle is not required to\n    be registered under
# the Motor Vehicles Act, 1988.\n15. IMT.  15. PERSONAL ACCIDENT COVER TO THE\n   INSURED OR ANY NAMED PERSON OTHER
# THAN\n    PAID  DRIVER OR CLEANER (Applicable to private\n    cars including three wheelers rated as private cars
# and\n    motorized two wheelers with or without side car (not\n     for hire or reward))\n\nSource:
# 3-years-private-car-liability-policy.txt\nown premises’ shall mean use only on insured’s premises\n    to which
# public have no general right of access.\n14. IMT. 15. PERSONAL ACCIDENT COVER TO THE INSURED\n   OR ANY NAMED
# PERSON OTHER THAN PAID DRIVER\n   OR CLEANER (Applicable to private cars including\n    three wheelers rated as
# private cars and motorized\n   two wheelers with or without side car
# Metric: Hallucination | Threshold: 0.5 | Success: False | Score: 1.0 | Cost: $0.01
#
# Reason: The score is 1.00 because the actual output makes broad exclusion and voidance claims that are not
# supported by the context, which only describes specific endorsements, permitted users, and limited site/premises
# restrictions.
# Verdict: Verdicts:
# [
#     {
#         "verdict": "no",
#         "reason": "The actual output contradicts the context in several places. The context only explicitly states
# that one endorsement applies while the vehicle is used by the insured or, with permission, by a
# member/director/employee for social, domestic, or pleasure purposes, and separately states a 'use confined to own
# premises' endorsement and a goods-carrying-vehicle site restriction. It does not support the broad claim that a
# privately used car policy with own-damage-plus-liability cover generally excludes all use outside insured premises,
# nor does it state that cover becomes 'void' for any unauthorized person in the broad way described. A safer
# correction would be: the excerpts describe specific endorsements and conditions, including social/domestic/pleasure
# use for certain permitted users, no indemnity if another policy applies, and no cover in certain endorsements when
# use is confined to own premises or sites."
#     }
# ]
